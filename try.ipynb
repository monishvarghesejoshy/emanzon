# %% [markdown]
# <a href="https://colab.research.google.com/github/monishvarghesejoshy/emanzon/blob/adf_publish/try.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
p=10
q=4
z=p/q
print (z)
# Out:
# 2.5

# %%
input1=int(input("enter first digit"))

match input1:
    case 1:
        print("one")
    case 2:
        print("two")
    case 3:
        print("three")
    case 4:
        print("four")
    case 5:
        print("five")
    case _ :
        print("invalid")
# Out:
# enter first digit8
# invalid

# %%
a=[1,2,3,4,5]
for i in a:
    if i%2==1:
        print(i ,"is odd")
    else:
        print(i, "is even")
# Out:
# 1 is odd
# 2 is even
# 3 is odd
# 4 is even
# 5 is odd

# %%
for i in range(2,30,1):
  for j in range(2,i):
     if (i%j) == 0:
      print(i, "is not a prime")
      break
  else:
    print(i, "is a prime")
# Out:
# 2 is a prime
# 3 is a prime
# 4 is not a prime
# 5 is a prime
# 6 is not a prime
# 7 is a prime
# 8 is not a prime
# 9 is not a prime
# 10 is not a prime
# 11 is a prime
# 12 is not a prime
# 13 is a prime
# 14 is not a prime
# 15 is not a prime
# 16 is not a prime
# 17 is a prime
# 18 is not a prime
# 19 is a prime
# 20 is not a prime
# 21 is not a prime
# 22 is not a prime
# 23 is a prime
# 24 is not a prime
# 25 is not a prime
# 26 is not a prime
# 27 is not a prime
# 28 is not a prime
# 29 is a prime

# %%
x=1
while x<7:

  print (x)

  x+=1
# Out:
# 1
# 2
# 3
# 4
# 5
# 6

# %%
def ab(x):
     if ( x <0):
        y= x*-1
     else:
       y=x
     return(y)
ab(7)
# Out:
# 7

# %%
def sum(n):
  result=0
  for i in range(1, n+1):
        result=result+i
        i=i+1
  return(result)
sum(6)
# Out:
# 21

# %%
name='Jacob'
'a' in name
# Out:
# True

# %%
word = '''God
is Love'''
"Love" in word
# Out:
# True

# %%
st=''' Work Hard and Work Smart'''
for c in st:
     print( c)
# Out:
#
# W
# o
# r
# k
#
# H
# a
# r
# d
#
# a
# n
# d
#
# W
# o
# r
# k
#
# S
# m
# a
# r
# t

# %%
s1="Hello "
s2=s1.strip()
s2
# Out:
# 'Hello'

# %%
s1.replace("He","ha")
# Out:
# 'hallo '

# %%
dict1={'Name': 'Monish', 'Age':41, 'Gender':'Male'}
dict1
# Out:
# {'Name': 'Monish', 'Age': 41, 'Gender': 'Male'}

# %%
dict1.keys()
# Out:
# dict_keys(['Name', 'Age', 'Gender'])

# %%
dict1.values()
# Out:
# dict_values(['Monish', 41, 'Male'])

# %%
dict1.items()
# Out:
# dict_items([('Name', 'Monish'), ('Age', 41), ('Gender', 'Male')])

# %%
dict1.items()
del dict1['Age']
dict1
# Out:
# {'Name': 'Monish'}

# %%
dict1.clear()
dict1
# Out:
# {}

# %%
num=int(input('Enter the number of Employees'))
count=1
employee=dict()
while count<= num:
  name=input('Enter the name')
  salary=int(input('Enter the salary'))
  employee[name]=salary
  count+=1
for name,salary in employee.items():
  print(name,salary)
# Out:
# Enter the number of Employees2
# Enter the namejosh
# Enter the salary5000
# Enter the namedan
# Enter the salary4000
# josh 5000
# dan 4000

# %%
import  numpy as np
x=np.array([1,2,3])
x
type(x)
y=np.ones((2,2), dtype=np.int16)
y
# Out:
# array([[1, 1],
#        [1, 1]], dtype=int16)

# %%
x=np.arange(10,80,5)
x
# Out:
# array([10, 15, 20, 25, 30, 35, 40, 45, 50, 55, 60, 65, 70, 75])

# %%
y=np.linspace(0,1/4,3)
y
# Out:
# array([0.   , 0.125, 0.25 ])

# %%
i=np.random.rand(3,4)
i
# Out:
# array([[0.23787674, 0.86355945, 0.8593668 , 0.23837462],
#        [0.78613028, 0.63356274, 0.22264688, 0.84030964],
#        [0.47084623, 0.57269373, 0.67461817, 0.46024784]])

# %%
j=np.empty((3,4), dtype=np.int16)

j
# Out:
# array([[    0,     0,     0,     0],
#        [    0,     0,     0, 16320],
#        [    0,     0,     0, 16336]], dtype=int16)
